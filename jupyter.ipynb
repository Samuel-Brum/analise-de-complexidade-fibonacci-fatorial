# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
fibonacciRecursivo = [0.00228, 0.00245, 0.00366, 0.00345, 0.00885, 0.04250, 0.49685, 5.31015, 57.67486]
fibonacciIterativo = [0.00151, 0.00150, 0.00151, 0.00167, 0.00133, 0.00140, 0.00156, 0.00378, 0.00219, 0.00211, 0.00227, 0.00337, 0.00371, 0.00251, 0.00288, 0.00413, 0.00296, 0.00279, 0.00427, 0.00366, 0.00255, 0.00686, 0.00943, 0.01491, 0.12675, 0.10644, 0.09743]

tamanhoFib = [5, 10, 15, 20, 25, 30, 35, 40, 45, 100, 200, 300, 400, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000, 2000000, 1500000, 1200000]

# %%
fatorialRecursivo = [0.002306, 0.002636, 0.002156, 0.002022, 0.002204, 0.002591, 0.002876, 0.002728, 0.002359, 0.002446, 0.003125, 0.00326, 0.00534]
fatorialIterativo = [0.001323, 0.001394, 0.001638, 0.001611, 0.001720, 0.001490, 0.001550, 0.001641, 0.001664, 0.001428, 0.001509, 0.001850, 0.001482]

tamanhoFat = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65]

# %%
fig, ax = plt.subplots()

ax.plot(tamanhoFib[:9], fibonacciRecursivo, 'ro', label='Fibonacci Recursivo')
ax.plot(tamanhoFib[:-18], fibonacciIterativo[:-18], 'bs', label='Fibonacci Iterativo')
ax.set_title("Fibonacci Recursivo X Fibonacci Iterativo", pad=20)
ax.set_xlabel("n")
ax.set_ylabel("Segundos")
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(tamanhoFib, fibonacciIterativo, 'bs', label='Fibonacci Iterativo')
ax.set_title("Fibonacci Iterativo (full range)", pad=20)
ax.set_xlabel("n")
ax.set_ylabel("Segundos")
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(tamanhoFat, fatorialRecursivo, 'ro', label='Fatorial Recursivo')
ax.plot(tamanhoFat, fatorialIterativo, 'bs', label='Fatorial Iterativo')
ax.set_title("Fatorial Recursivo X Fatorial Iterativo", pad=20)
ax.set_xlabel("n")
ax.set_ylabel("Segundos")
ax.legend()

plt.show()
